# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt 
import seaborn as sns 
# %matplotlib inline 
sns.set()

# %%
insurance = pd.read_csv("insurance.csv")
insurance
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
insurance.head(20)
# Out:
#     age     sex     bmi  children smoker     region      charges
# 0    19  female  27.900         0    yes  southwest  16884.92400
# 1    18    male  33.770         1     no  southeast   1725.55230
# 2    28    male  33.000         3     no  southeast   4449.46200
# 3    33    male  22.705         0     no  northwest  21984.47061
# 4    32    male  28.880         0     no  northwest   3866.85520
# 5    31  female  25.740         0     no  southeast   3756.62160
# 6    46  female  33.440         1     no  southeast   8240.58960
# 7    37  female  27.740         3     no  northwest   7281.50560
# 8    37    male  29.830         2     no  northeast   6406.41070
# 9    60  female  25.840         0     no  northwest  28923.13692
# 10   25    male  26.220         0     no  northeast   2721.32080
# 11   62  female  26.290         0    yes  southeast  27808.72510
# 12   23    male  34.400         0     no  southwest   1826.84300
# ...

# %%
insurance.tail(20)
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1318   35    male  39.710         4     no  northeast  19496.71917
# 1319   39  female  26.315         2     no  northwest   7201.70085
# 1320   31    male  31.065         3     no  northwest   5425.02335
# 1321   62    male  26.695         0    yes  northeast  28101.33305
# 1322   62    male  38.830         0     no  southeast  12981.34570
# 1323   42  female  40.370         2    yes  southeast  43896.37630
# 1324   31    male  25.935         1     no  northwest   4239.89265
# 1325   61    male  33.535         0     no  northeast  13143.33665
# 1326   42  female  32.870         0     no  northeast   7050.02130
# 1327   51    male  30.030         1     no  southeast   9377.90470
# 1328   23  female  24.225         2     no  northeast  22395.74424
# 1329   52    male  38.600         2     no  southwest  10325.20600
# 1330   57  female  25.740         2     no  southeast  12629.16560
# ...

# %%
insurance.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
insurance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1338 entries, 0 to 1337
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1338 non-null   int64
#  1   sex       1338 non-null   object
#  2   bmi       1338 non-null   float64
#  3   children  1338 non-null   int64
#  4   smoker    1338 non-null   object
#  5   region    1338 non-null   object
#  6   charges   1338 non-null   float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 73.3+ KB

# %%
insurance.isnull().any()
# Out:
# age         False
# sex         False
# bmi         False
# children    False
# smoker      False
# region      False
# charges     False
# dtype: bool

# %%
insurance.duplicated().any()
# Out:
# np.True_

# %%
insurance.drop_duplicates()
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1337 rows x 7 columns]

# %%
insurance['sex']=insurance['sex'].replace({'male':0 ,'female':1})
insurance
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_9984\1365487213.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   insurance['sex']=insurance['sex'].replace({'male':0 ,'female':1})
#       age  sex     bmi  children smoker     region      charges
# 0      19    1  27.900         0    yes  southwest  16884.92400
# 1      18    0  33.770         1     no  southeast   1725.55230
# 2      28    0  33.000         3     no  southeast   4449.46200
# 3      33    0  22.705         0     no  northwest  21984.47061
# 4      32    0  28.880         0     no  northwest   3866.85520
# ...   ...  ...     ...       ...    ...        ...          ...
# 1333   50    0  30.970         3     no  northwest  10600.54830
# ...

# %%
insurance['smoker']=insurance['smoker'].replace({'no':0 ,'yes':1})
insurance
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_9984\1668294214.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   insurance['smoker']=insurance['smoker'].replace({'no':0 ,'yes':1})
#       age  sex     bmi  children  smoker     region      charges
# 0      19    1  27.900         0       1  southwest  16884.92400
# 1      18    0  33.770         1       0  southeast   1725.55230
# 2      28    0  33.000         3       0  southeast   4449.46200
# 3      33    0  22.705         0       0  northwest  21984.47061
# 4      32    0  28.880         0       0  northwest   3866.85520
# ...   ...  ...     ...       ...     ...        ...          ...
# 1333   50    0  30.970         3       0  northwest  10600.54830
# ...

# %%
insurance['region'].value_counts()
# Out:
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %%
insurance['region']=insurance['region'].replace({'northeast':1,'northwest':2,'southeast':3,'southwest':4})
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_9984\2195906532.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   insurance['region']=insurance['region'].replace({'northeast':1,'northwest':2,'southeast':3,'southwest':4})

# %%
insurance['region']
# Out:
# 0       4
# 1       3
# 2       3
# 3       2
# 4       2
#        ..
# 1333    2
# 1334    1
# 1335    3
# 1336    4
# 1337    2
# Name: region, Length: 1338, dtype: int64

# %%
insurance['charges']= insurance['charges'].astype(int)
insurance['charges']
# Out:
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
#         ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
# Name: charges, Length: 1338, dtype: int64

# %%
sns.histplot(insurance['charges'], kde=True, color='blue')
plt.title("Distribution of insurance by region")
plt.show()

# %%
sns.kdeplot(insurance[insurance['charges'] >= 13270]['age'], label='Distribution of insurance charges more than mean by age', fill=True)
sns.kdeplot(insurance[insurance['charges'] <= 13270]['age'], label='Distribution of insurance charges less than mean by age', fill=True)
plt.title("Insurance Charges Distribution by mean value")
plt.show()

# %%
sns.histplot(insurance['bmi'], kde=True, color='red')
plt.title("Distribution of insurance by BMI")
plt.show()

# %%
insurance.hist(figsize=(12, 8), bins=20)
plt.suptitle("Histogram for All Columns")
plt.show()

# %%
x= insurance.drop(columns= 'charges')
x
# Out:
#       age  sex     bmi  children  smoker  region
# 0      19    1  27.900         0       1       4
# 1      18    0  33.770         1       0       3
# 2      28    0  33.000         3       0       3
# 3      33    0  22.705         0       0       2
# 4      32    0  28.880         0       0       2
# ...   ...  ...     ...       ...     ...     ...
# 1333   50    0  30.970         3       0       2
# 1334   18    1  31.920         0       0       1
# 1335   18    1  36.850         0       0       3
# 1336   21    1  25.800         0       0       4
# 1337   61    1  29.070         0       1       2
#
# [1338 rows x 6 columns]

# %%
y= insurance['charges']
y
# Out:
# 0       16884
# 1        1725
# 2        4449
# 3       21984
# 4        3866
#         ...
# 1333    10600
# 1334     2205
# 1335     1629
# 1336     2007
# 1337    29141
# Name: charges, Length: 1338, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train , y_test=train_test_split(x,y,test_size=0.2,shuffle=True,random_state =0)

# %%
from sklearn.preprocessing import StandardScaler
sc= StandardScaler()

# %%
x_train_scaled= sc.fit_transform(X_train)

# %%
x_test_scaled= sc.transform(X_test)

# %%
from sklearn.ensemble import GradientBoostingRegressor
gbr= (GradientBoostingRegressor
    n_estimators= 700 ,
    max_depth =20 , 
    min_samples_split= 5,
    min_samples_leaf=2 , 
    max_features= 'sqrt',
    random_state=42
)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(max_depth=20, max_features='sqrt', min_samples_leaf=2,
#                       min_samples_split=5, n_estimators=700, random_state=42)

# %%
y_predict= rf.predict(X_test)

# %%
from sklearn.metrics import r2_score , mean_squared_error

# %%
r2_score(y_test,y_predict)
# Out:
# 0.8907883814144136

# %%
mse = mean_squared_error(y_test,y_predict)

# %%
from math import sqrt
rmsr=sqrt(mse)
rmsr
# Out:
# 4212.188462917141

# %%
from sklearn.ensemble import GradientBoostingRegressor

model = GradientBoostingRegressor(
    n_estimators=100,
    learning_rate=0.1,
    random_state=42)

# %%
model.fit(X_train, y_train)
# Out:
# GradientBoostingRegressor(random_state=42)

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 16219696.047583807

# %%
r2 = r2_score(y_test, y_pred)
r2
# Out:
# 0.8980730517894937

# %%
import pickle

# %%
with open ('gbr_model.pkl','wb')as f:
    pickle.dump(model,f)
